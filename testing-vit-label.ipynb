# %%
# !pip install torch torchvision timm
# Download latest version
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

# Core tf.keras
from tensorflow.keras import layers, models, optimizers, applications
from tensorflow.keras import backend as K
from tensorflow.keras import Input, Model, Sequential

# Layers
from tensorflow.keras.layers import (
    Dense,
    Dropout,
    Flatten,
    Conv2D,
    MaxPooling2D,
    GlobalAveragePooling2D,
    Input
)

# Optimizers
from tensorflow.keras.optimizers import Adam, SGD

# Callbacks
from tensorflow.keras.callbacks import (
    ModelCheckpoint,
    EarlyStopping,
    LearningRateScheduler,
    TensorBoard
)
import torch
import torch.nn as nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import timm

# %%
# ========================= CONFIG =========================
# ⚠️ Change these paths to match your local setup
MODEL_PATH = "./nih_model0.43F1.pth"
IMAGE_PATH = "./mutli_label_image1.png"

# %%
# ========================= RUN INFERENCE =========================
# Load model once
model, thresholds = load_model(MODEL_PATH)

# Predict on single image
results, img = predict(model, thresholds, IMAGE_PATH)
print_results(results, IMAGE_PATH)
display_results(results, img, IMAGE_PATH)
# Out:
# Loading model …
# ✅ Model loaded  |  Best F1: 0.4070  AUC: 0.8317
#    Trained at epoch: 4
#
# ...
#   Results for: mutli_label_image1.png
# ...
#   Effusion         0.616  t=0.64    negative  ████████████
#   Infiltration     0.535  t=0.56    negative  ██████████
#   Pneumothorax     0.412  t=0.73    negative  ████████
#   Atelectasis      0.593  t=0.61    negative  ███████████
#   Mass             0.459  t=0.76    negative  █████████
#   Cardiomegaly     0.822  t=0.79  ✅ POSITIVE  ████████████████
#   Nodule           0.518  t=0.66    negative  ██████████
#   Emphysema        0.418  t=0.76    negative  ████████
# ...
#
#   ⚠️  Detected: Cardiomegaly
# 💾 Saved as prediction_result.png
